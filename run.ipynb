# %% [markdown]
# # Run script
#
# This is the entry point for running the pipeline. It is formatted in a notebook to ba campatible with Google colab/Kaggle. Simply run the cells to execute the pipeline

# %%
print('test')
# Out:
# test

# %% [markdown]
# Start by installing requirements and train the model for a specified number of epochs with config

# %% [markdown]
# Mount google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Copy over data to working dir.

# %%
# !cp -r /content/drive/MyDrive/oral_cancer_data/dataset /content/dataset

# %%
# !ls /content/dataset
# Out:
# BF  FL	sampleSubmission.csv  train.csv

# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/edvardschmidt33/oral_cancer_classification.git /content/project
# Out:
# Cloning into '/content/project'...
# remote: Enumerating objects: 38, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 38 (delta 7), reused 36 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (38/38), 16.36 KiB | 465.00 KiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd /content/project
# Out:
# /content/project

# %% [markdown]
# Download requirements

# %%
# !pip install -r requirements.txt

# %%
# !mv /content/dataset /content/project/dataset

# %% [markdown]
# Train the model

# %%
# !pip install -q timm pyyaml

# %%
import torch
print('cuda:', torch.cuda.is_available(), '|', torch.cuda.get_device_name(0) if torch.cuda.is_available() else '')
# Out:
# cuda: True | Tesla T4

# %% [markdown]
# Smoke test

# %%
# !python -m src.train --config configs/config.yaml --fold 0 --smoke
# Out:
# [fold 0] train patients: ['05', '07', '10', '11', '14', '15', '16', '18']
# [fold 0] val   patients: ['03', '09', '13', '17']
# [fold 1] train patients: ['03', '05', '07', '09', '13', '14', '15', '17']
# [fold 1] val   patients: ['10', '11', '16', '18']
# [fold 2] train patients: ['03', '09', '10', '11', '13', '16', '17', '18']
# [fold 2] val   patients: ['05', '07', '14', '15']
# fold 0: 74302 train cells, 40000 val cells
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# ...
# model.safetensors: 100% 62.5M/62.5M [00:01<00:00, 55.0MB/s]
# ...

# %%
# !ls dataset/BF/train | wc -l
# !ls dataset/FL/train | wc -l
# !wc -l dataset/train.csv
# !ls dataset/BF/train/pat_11_image_9764.jpg 2>&1
# !ls dataset/BF/train/ | grep pat_11 | wc -l
# Out:
# 0
# 0
# 114303 dataset/train.csv
# ls: cannot access 'dataset/BF/train/pat_11_image_9764.jpg': No such file or directory
# 0
